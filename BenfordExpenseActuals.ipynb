# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
pd.options.display.max_rows = 16

# %%
expenseactuals = pd.read_csv('Expense_Actuals.csv') #importing file with data

# %%
expenseactuals
# Out:
#       PUBLICATION DATE  FISCAL YEAR AGENCY CODE  \
# 0             20171130         2011         991
# 1             20171130         2002         858
# 2             20171130         2008         817
# 3             20171130         2009         991
# 4             20171130         2008         819
# ...                ...          ...         ...
# 1483          20171130         2011         039
# 1484          20171130         2008         035
# 1485          20171130         2008         012
# 1486          20171130         2010         010
# 1487          20171201         2017         015
#
#                          AGENCY NAME  ALL FUNDS  CITY FUND  REMARK
# 0                    General Reserve          0          0     NaN
# 1                         D.O.I.T.T.     170951      53506     NaN
# 2              Dept of Mental Health          0          0     NaN
# 3                    General Reserve          0          0     NaN
# 4                 Health + Hospitals     256837     128181     NaN
# ...                              ...        ...        ...     ...
# 1483   Queens Borough Public Library      81264      80988     NaN
# 1484    NY Public Library - Research      24326      24326     NaN
# 1485   President,Borough of Brooklyn       8088       7981     NaN
# 1486  President,Borough of Manhattan       4699       4350     NaN
# 1487       Office of the Comptroller      93617      71282     NaN
#
# [1488 rows x 7 columns]

# %%
all_funds = expenseactuals["ALL FUNDS"].tolist()

# %%
all_funds
# Out:
# [0,
#  170951,
#  0,
#  0,
#  256837,
#  462900,
#  2821,
#  47299,
#  2727,
#  231227,
#  124680,
#  30790,
#  108943,
#  6129,
#  4407,
#  2551,
#  342,
#  471,
#  3170,
#  0,
#  22978,
#  7463,
#  153014,
#  1624,
#  1482,
#  11407,
#  89660,
#  97229,
#  408030,
#  56378,
#  1436161,
#  276078,
#  909465,
#  0,
#  668217,
#  1005312,
#  2779,
#  183819,
#  515126,
#  270834,
#  621330,
#  643875,
#  4219,
#  14302,
#  83127,
#  45355,
#  80626,
#  39448,
#  7070,
#  16012,
#  915,
#  329,
#  439,
#  343,
#  237,
#  -557916,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1390354,
#  -2263063,
#  41615432,
#  225236,
#  1854,
#  44921,
#  2586,
#  229491,
#  120425,
#  33047,
#  108402,
#  6733,
#  2262,
#  475,
#  480,
#  3046,
#  1660,
#  21534,
#  7756,
#  157461,
#  1547,
#  1545,
#  11536,
#  83205,
#  41954,
#  389902,
#  57862,
#  1428497,
#  0,
#  914973,
#  0,
#  701640,
#  991439,
#  4685,
#  181778,
#  501447,
#  254169,
#  162386,
#  683421,
#  190359,
#  4219,
#  13948,
#  78975,
#  42730,
#  72604,
#  38756,
#  6352,
#  15110,
#  992,
#  331,
#  419,
#  344,
#  223,
#  -372892,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1110255,
#  736774,
#  45177308,
#  501534,
#  2069,
#  46465,
#  2998,
#  228593,
#  118141,
#  35386,
#  93009,
#  7200,
#  2422,
#  478,
#  461,
#  3127,
#  4,
#  23170,
#  7243,
#  244445,
#  1438,
#  1552,
#  11964,
#  79282,
#  112277,
#  418602,
#  57895,
#  1470614,
#  0,
#  946842,
#  0,
#  709230,
#  998001,
#  4383,
#  220635,
#  501650,
#  261616,
#  82566,
#  688750,
#  201380,
#  4160,
#  14627,
#  78878,
#  43410,
#  69994,
#  38350,
#  6897,
#  15510,
#  964,
#  320,
#  403,
#  344,
#  234,
#  -311474,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1213036,
#  705916,
#  356,
#  47728791,
#  110772,
#  3110,
#  47428,
#  3020,
#  231264,
#  122237,
#  37278,
#  95827,
#  9715,
#  2518,
#  538,
#  483,
#  3329,
#  0,
#  24847,
#  6680,
#  246167,
#  1423,
#  1611,
#  12312,
#  78410,
#  108277,
#  473873,
#  64273,
#  1443466,
#  0,
#  1125427,
#  0,
#  755584,
#  1034946,
#  4816,
#  202146,
#  553590,
#  287086,
#  85061,
#  762188,
#  223681,
#  4329,
#  15386,
#  79272,
#  44219,
#  72683,
#  39299,
#  6977,
#  15433,
#  1030,
#  308,
#  350,
#  269,
#  -338787,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1279242,
#  1805707,
#  53632988,
#  10000,
#  2903,
#  49000,
#  3117,
#  268241,
#  136303,
#  44907,
#  104291,
#  9285,
#  2658,
#  729,
#  465,
#  3680,
#  0,
#  25998,
#  6526,
#  303039,
#  1435,
#  1702,
#  13027,
#  79771,
#  125295,
#  543240,
#  81526,
#  1509524,
#  0,
#  1590636,
#  0,
#  804393,
#  1094894,
#  4957,
#  200527,
#  623223,
#  308203,
#  87866,
#  855828,
#  237224,
#  4592,
#  15561,
#  81147,
#  45804,
#  76019,
#  41788,
#  6964,
#  16081,
#  1086,
#  317,
#  454,
#  414,
#  339,
#  -673255,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1396500,
#  372197,
#  54713948,
#  10000,
#  3031,
#  50588,
#  3630,
#  271907,
#  149996,
#  51289,
#  127676,
#  11308,
#  2845,
#  785,
#  530,
#  4224,
#  0,
#  25953,
#  6673,
#  310561,
#  1741,
#  1819,
#  13165,
#  80679,
#  122408,
#  576104,
#  87195,
#  1561741,
#  0,
#  810252,
#  0,
#  868771,
#  1173420,
#  5166,
#  205866,
#  618376,
#  332561,
#  96247,
#  934640,
#  255567,
#  4729,
#  17113,
#  86427,
#  47699,
#  79286,
#  44351,
#  7595,
#  16782,
#  1104,
#  429,
#  501,
#  408,
#  348,
#  -658175,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1387014,
#  1955309,
#  59811575,
#  2750,
#  3115,
#  51211,
#  3812,
#  290487,
#  161276,
#  56679,
#  130984,
#  12979,
#  2925,
#  764,
#  583,
#  4408,
#  0,
#  27763,
#  6779,
#  384061,
#  1882,
#  1861,
#  13620,
#  81589,
#  136557,
#  597994,
#  99410,
#  1586921,
#  0,
#  919095,
#  1244392,
#  5771,
#  215498,
#  697786,
#  370648,
#  96541,
#  997469,
#  308265,
#  5889,
#  20513,
#  90264,
#  50762,
#  83584,
#  47033,
#  8311,
#  17778,
#  1143,
#  418,
#  536,
#  421,
#  362,
#  -615910,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1477192,
#  1602961,
#  62588853,
#  0,
#  2809,
#  49526,
#  4330,
#  290255,
#  151387,
#  58423,
#  134506,
#  13439,
#  2884,
#  766,
#  607,
#  4599,
#  0,
#  28875,
#  7130,
#  382705,
#  1898,
#  1882,
#  13936,
#  82134,
#  153491,
#  702224,
#  109678,
#  1712205,
#  0,
#  204573,
#  0,
#  1034095,
#  1258215,
#  6272,
#  225096,
#  787993,
#  379595,
#  102107,
#  1092350,
#  370044,
#  5933,
#  21540,
#  96919,
#  50463,
#  84282,
#  45764,
#  8305,
#  17679,
#  1148,
#  508,
#  493,
#  436,
#  365,
#  -576485,
#  0,
#  0,
#  0,
#  0,
#  -1630725,
#  -2496716,
#  60779779,
#  0,
#  2573,
#  51478,
#  4221,
#  281619,
#  142906,
#  60073,
#  138353,
#  23636,
#  3189,
#  751,
#  554,
#  4608,
#  0,
#  30098,
#  6899,
#  405899,
#  1909,
#  2030,
#  13980,
#  82973,
#  159610,
#  727910,
#  101530,
#  1685452,
#  0,
#  195610,
#  0,
#  1470930,
#  1301194,
#  6930,
#  230898,
#  800752,
#  382715,
#  107463,
#  1077558,
#  368768,
#  5207,
#  22340,
#  102837,
#  52008,
#  87306,
#  48845,
#  8599,
#  18507,
#  1168,
#  426,
#  549,
#  424,
#  376,
#  -941650,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1782184,
#  -1892941,
#  63390689,
#  0,
#  2212,
#  52111,
#  4445,
#  263711,
#  144050,
#  61769,
#  203357,
#  57619,
#  3397,
#  726,
#  491,
#  4479,
#  0,
#  30177,
#  6136,
#  350263,
#  1981,
#  2013,
#  14020,
#  81890,
#  148746,
#  705427,
#  98974,
#  1626906,
#  0,
#  184402,
#  23322,
#  1021577,
#  1408383,
#  6851,
#  219737,
#  864913,
#  393740,
#  111878,
#  1117608,
#  415382,
#  5179,
#  21828,
#  104690,
#  51068,
#  84987,
#  48036,
#  8611,
#  17898,
#  1126,
#  388,
#  553,
#  425,
#  375,
#  -508344,
#  0,
#  0,
#  0,
#  0,
#  -1851036,
#  95890,
#  65876253,
#  0,
#  2236,
#  51900,
#  4410,
#  257781,
#  147749,
#  83199,
#  0,
#  14227,
#  3693,
#  627,
#  651,
#  4273,
#  0,
#  31716,
#  6033,
#  325034,
#  1960,
#  2113,
#  14315,
#  79679,
#  137633,
#  731343,
#  95062,
#  1569569,
#  0,
#  207544,
#  30465,
#  1059047,
#  1281218,
#  6794,
#  221346,
#  839795,
#  361329,
#  127276,
#  1091245,
#  452499,
#  5191,
#  26264,
#  105205,
#  50167,
#  87341,
#  49347,
#  8690,
#  17830,
#  1184,
#  481,
#  472,
#  421,
#  376,
#  -332715,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1743359,
#  -1279934,
#  67527971,
#  0,
#  2243,
#  51591,
#  262152,
#  146482,
#  83053,
#  0,
#  13223,
#  3889,
#  421,
#  767,
#  4452,
#  1381,
#  36743,
#  6131,
#  345896,
#  2032,
#  2106,
#  14387,
#  81697,
#  150340,
#  675260,
#  102482,
#  1505970,
#  0,
#  507226,
#  30726,
#  1727259,
#  1369768,
#  6995,
#  222290,
#  833340,
#  426328,
#  138142,
#  1177553,
#  431624,
#  5470,
#  27286,
#  104551,
#  52873,
#  88348,
#  50497,
#  8943,
#  18146,
#  1335,
#  538,
#  531,
#  449,
#  441,
#  -346521,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1713507,
#  571683,
#  71562342,
#  0,
#  2322,
#  51541,
#  4753,
#  263876,
#  156509,
#  82449,
#  0,
#  13713,
#  3998,
#  464,
#  799,
#  4743,
#  14,
#  46394,
#  5582,
#  404446,
#  2054,
#  2101,
#  14536,
#  83181,
#  202310,
#  689972,
#  98679,
#  1423185,
#  0,
#  337074,
#  31346,
#  1192581,
#  1414222,
#  7259,
#  240289,
#  860606,
#  413278,
#  127267,
#  1201704,
#  467486,
#  5610,
#  32474,
#  97595,
#  55675,
#  87844,
#  53113,
#  9294,
#  18196,
#  1397,
#  532,
#  604,
#  471,
#  450,
#  -1736861,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1764089,
#  -839293,
#  0,
#  2747,
#  56911,
#  5587,
#  285236,
#  163688,
#  83122,
#  0,
#  14678,
#  3944,
#  701,
#  735,
#  4782,
#  0,
#  52446,
#  5795,
#  581885,
#  2193,
#  1754,
#  15093,
#  89942,
#  273458,
#  718403,
#  108673,
#  1495547,
#  0,
#  335141,
#  34371,
#  1216054,
#  1477412,
#  8065,
#  251755,
#  884996,
#  496268,
#  160279,
#  1157782,
#  491716,
#  6252,
#  37435,
#  107621,
#  60989,
#  94065,
#  56953,
#  10302,
#  19206,
#  1504,
#  603,
#  641,
#  484,
#  477,
#  -884826,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1973725,
#  0,
#  3312,
#  59787,
#  5548,
#  305379,
#  163106,
#  91390,
#  0,
#  15663,
#  3991,
#  764,
#  781,
#  5251,
#  0,
#  47931,
#  8842,
#  664715,
#  2380,
#  2198,
#  15759,
#  89049,
#  282466,
#  850032,
#  134725,
#  1450674,
#  0,
#  959135,
#  36344,
#  1267157,
#  1500676,
#  8092,
#  258848,
#  910278,
#  476104,
#  399287,
#  1117778,
#  587010,
#  7731,
#  36211,
#  109626,
#  61575,
#  97047,
#  59265,
#  10705,
#  21600,
#  1600,
#  616,
#  686,
#  503,
#  559,
#  -714655,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1922463,
#  410767,
#  73410769,
#  1496355,
#  78581696,
#  80538509,
#  0,
#  3525,
#  62164,
#  5914,
#  333483,
#  182593,
#  99856,
#  0,
#  15841,
#  4123,
#  887,
#  1038,
#  5476,
#  0,
#  45778,
#  10427,
#  719232,
#  2429,
#  2220,
#  16207,
#  94499,
#  259982,
#  1026604,
#  150351,
#  1622380,
#  0,
#  883447,
#  39011,
#  1435894,
#  1601317,
#  9559,
#  266623,
#  957885,
#  532557,
#  505554,
#  1165866,
#  637604,
#  7726,
#  36105,
#  116911,
#  73639,
#  98216,
#  62820,
#  14574,
#  22078,
#  1614,
#  625,
#  772,
#  519,
#  517,
#  -486397,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -2052541,
#  142620,
#  84095876,
#  1368641,
#  1522,
#  1879,
#  2257324,
#  0,
#  6647548,
#  111216,
#  6099,
#  63101,
#  5614,
#  9645,
#  8658,
#  9771190,
#  4689,
#  59788,
#  137435,
#  9513785,
#  1400629,
#  23508038,
#  18154,
#  70885,
#  9691,
#  4425,
#  125979,
#  9392905,
#  85666,
#  1640,
#  6389179,
#  9563424,
#  139774,
#  764705,
#  135033,
#  133792,
#  33826,
#  0,
#  900061,
#  0,
#  20087,
#  5172,
#  18754,
#  830,
#  6926,
#  1521281,
#  96464,
#  2345517,
#  3589601,
#  855,
#  17903053,
#  22074,
#  984265,
#  1045113,
#  0,
#  11279,
#  3277,
#  55630,
#  1879465,
#  ...]

# %%
city_fund = expenseactuals["CITY FUND"].tolist()

# %%
city_fund
# Out:
# [0,
#  53506,
#  0,
#  0,
#  128181,
#  462900,
#  2821,
#  47094,
#  2650,
#  166267,
#  122942,
#  26105,
#  74565,
#  5900,
#  4372,
#  2551,
#  342,
#  471,
#  2651,
#  0,
#  22597,
#  3192,
#  93681,
#  1624,
#  1330,
#  11407,
#  59297,
#  88086,
#  63211,
#  55750,
#  448564,
#  84754,
#  826437,
#  0,
#  626224,
#  909920,
#  2627,
#  179816,
#  271260,
#  167554,
#  27269,
#  162231,
#  3303,
#  12258,
#  67086,
#  38992,
#  71802,
#  35201,
#  6045,
#  13986,
#  915,
#  329,
#  439,
#  343,
#  237,
#  -413262,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -2263063,
#  26567991,
#  225236,
#  1854,
#  43876,
#  2531,
#  116533,
#  119435,
#  26492,
#  76845,
#  5812,
#  2262,
#  475,
#  480,
#  2450,
#  1660,
#  21527,
#  3222,
#  89980,
#  1547,
#  1378,
#  11531,
#  54502,
#  18958,
#  57098,
#  57445,
#  518987,
#  0,
#  826572,
#  0,
#  655668,
#  956840,
#  4680,
#  176556,
#  255506,
#  159653,
#  6437,
#  143601,
#  70636,
#  3386,
#  12153,
#  63777,
#  35897,
#  61516,
#  32592,
#  5430,
#  12920,
#  992,
#  331,
#  419,
#  344,
#  223,
#  -177968,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  736774,
#  29935781,
#  501534,
#  2069,
#  45461,
#  2963,
#  88119,
#  117152,
#  29869,
#  62859,
#  6199,
#  2422,
#  474,
#  461,
#  2539,
#  4,
#  23165,
#  2828,
#  115124,
#  1438,
#  1411,
#  11940,
#  56678,
#  36454,
#  56286,
#  57770,
#  555913,
#  0,
#  818027,
#  0,
#  661120,
#  965605,
#  4378,
#  201277,
#  280376,
#  184255,
#  0,
#  136922,
#  82439,
#  3698,
#  11799,
#  66875,
#  36602,
#  61268,
#  34698,
#  5765,
#  13490,
#  964,
#  320,
#  403,
#  344,
#  234,
#  -329182,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  705916,
#  356,
#  32575676,
#  110772,
#  3110,
#  46329,
#  3009,
#  99697,
#  120563,
#  31100,
#  68299,
#  8205,
#  2518,
#  538,
#  483,
#  2877,
#  0,
#  24847,
#  2590,
#  126952,
#  1423,
#  1456,
#  12285,
#  60587,
#  31075,
#  53362,
#  64240,
#  539751,
#  0,
#  997358,
#  0,
#  704929,
#  1009084,
#  4816,
#  197565,
#  300156,
#  202613,
#  0,
#  150719,
#  101330,
#  3678,
#  12934,
#  64975,
#  37902,
#  66247,
#  34351,
#  5902,
#  13511,
#  1030,
#  308,
#  350,
#  269,
#  -225860,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1805707,
#  36947700,
#  10000,
#  2903,
#  47886,
#  3117,
#  132764,
#  134266,
#  37132,
#  76493,
#  8188,
#  2658,
#  729,
#  465,
#  2945,
#  0,
#  25554,
#  2457,
#  180391,
#  1435,
#  1534,
#  13007,
#  60637,
#  38369,
#  68516,
#  81467,
#  587106,
#  0,
#  1469669,
#  0,
#  757796,
#  1049104,
#  4957,
#  196201,
#  337331,
#  221867,
#  3235,
#  153615,
#  107867,
#  3886,
#  12781,
#  68466,
#  38857,
#  67447,
#  35567,
#  5958,
#  14141,
#  1086,
#  317,
#  454,
#  414,
#  339,
#  -453519,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  372197,
#  38370483,
#  10000,
#  3031,
#  50588,
#  3630,
#  133165,
#  147812,
#  42585,
#  85206,
#  9426,
#  2845,
#  785,
#  530,
#  3550,
#  0,
#  25953,
#  2683,
#  210724,
#  1741,
#  1634,
#  13131,
#  62434,
#  55308,
#  74217,
#  87086,
#  589107,
#  0,
#  663259,
#  0,
#  808320,
#  1144784,
#  5135,
#  200698,
#  358108,
#  250150,
#  4671,
#  179008,
#  132641,
#  4078,
#  15398,
#  71183,
#  41163,
#  70429,
#  37909,
#  6591,
#  15066,
#  1104,
#  429,
#  501,
#  408,
#  348,
#  -514796,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1955309,
#  42697117,
#  2750,
#  3115,
#  51211,
#  3812,
#  139140,
#  159002,
#  43965,
#  97632,
#  11195,
#  2925,
#  764,
#  583,
#  3727,
#  0,
#  27763,
#  2506,
#  259368,
#  1882,
#  1671,
#  13601,
#  64131,
#  75386,
#  75273,
#  99387,
#  570456,
#  0,
#  849897,
#  1206386,
#  5771,
#  210240,
#  421804,
#  277209,
#  7579,
#  195882,
#  179365,
#  5178,
#  17052,
#  74669,
#  43715,
#  73589,
#  40364,
#  7231,
#  16105,
#  1143,
#  418,
#  536,
#  421,
#  362,
#  -398740,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1602961,
#  43931950,
#  0,
#  2809,
#  49482,
#  4330,
#  166283,
#  148586,
#  44666,
#  96496,
#  11632,
#  2884,
#  766,
#  607,
#  3858,
#  0,
#  28875,
#  2496,
#  254942,
#  1898,
#  1690,
#  13882,
#  62980,
#  75404,
#  74461,
#  109677,
#  656111,
#  0,
#  94267,
#  0,
#  907759,
#  1221933,
#  6264,
#  218656,
#  457419,
#  279250,
#  9360,
#  216716,
#  220647,
#  5278,
#  18506,
#  74574,
#  43263,
#  73393,
#  40715,
#  7235,
#  15725,
#  1148,
#  508,
#  493,
#  436,
#  365,
#  -452764,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -2496716,
#  40960287,
#  0,
#  2573,
#  51478,
#  4221,
#  158078,
#  140567,
#  45885,
#  103915,
#  22171,
#  3189,
#  751,
#  554,
#  4090,
#  0,
#  30098,
#  2308,
#  220245,
#  1909,
#  1831,
#  13931,
#  62683,
#  53278,
#  68171,
#  101530,
#  641651,
#  0,
#  88756,
#  0,
#  1138928,
#  1267964,
#  6914,
#  224716,
#  434353,
#  273753,
#  3671,
#  218360,
#  219914,
#  4740,
#  17425,
#  82882,
#  45749,
#  78033,
#  43733,
#  7671,
#  16904,
#  1168,
#  426,
#  549,
#  424,
#  376,
#  -854416,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1892941,
#  41868262,
#  0,
#  2212,
#  52111,
#  4445,
#  141246,
#  141448,
#  47080,
#  165933,
#  56968,
#  3397,
#  726,
#  491,
#  3989,
#  0,
#  30171,
#  1916,
#  223489,
#  1981,
#  1807,
#  14020,
#  61393,
#  60588,
#  59108,
#  98474,
#  606402,
#  0,
#  83598,
#  23322,
#  924669,
#  1370065,
#  6843,
#  214418,
#  421005,
#  267588,
#  1128,
#  210887,
#  261626,
#  4802,
#  17053,
#  77508,
#  44604,
#  76253,
#  42367,
#  7517,
#  15977,
#  1126,
#  388,
#  553,
#  425,
#  375,
#  -383838,
#  0,
#  0,
#  0,
#  0,
#  0,
#  95890,
#  44659685,
#  0,
#  2236,
#  51900,
#  4358,
#  144643,
#  144648,
#  75704,
#  0,
#  13392,
#  3693,
#  627,
#  651,
#  3720,
#  0,
#  31716,
#  2054,
#  213642,
#  1960,
#  1868,
#  14315,
#  59492,
#  73018,
#  35819,
#  95062,
#  612631,
#  0,
#  75477,
#  30465,
#  942522,
#  1241535,
#  6743,
#  216702,
#  415585,
#  257066,
#  1268,
#  199548,
#  264529,
#  4278,
#  21104,
#  79331,
#  43767,
#  73329,
#  42670,
#  7591,
#  15827,
#  1184,
#  481,
#  472,
#  421,
#  376,
#  -215463,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1279934,
#  47544093,
#  0,
#  2242,
#  51591,
#  138276,
#  142423,
#  78060,
#  0,
#  12229,
#  3889,
#  421,
#  767,
#  3893,
#  1381,
#  36527,
#  2125,
#  241438,
#  2032,
#  1893,
#  14387,
#  58684,
#  47081,
#  45884,
#  97893,
#  616438,
#  0,
#  70765,
#  30693,
#  977379,
#  1242560,
#  6769,
#  217216,
#  413531,
#  262857,
#  8545,
#  201079,
#  259150,
#  4667,
#  23004,
#  85500,
#  45732,
#  78166,
#  44274,
#  8027,
#  16218,
#  1335,
#  538,
#  531,
#  449,
#  441,
#  -173848,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  571683,
#  50315020,
#  0,
#  2322,
#  51529,
#  4753,
#  152309,
#  149470,
#  82426,
#  0,
#  12713,
#  3998,
#  464,
#  799,
#  4221,
#  14,
#  46394,
#  1682,
#  296762,
#  2054,
#  1900,
#  14507,
#  59453,
#  65592,
#  58802,
#  98489,
#  641549,
#  0,
#  129268,
#  31346,
#  1018639,
#  1385890,
#  6788,
#  235703,
#  453685,
#  300589,
#  2144,
#  220700,
#  307286,
#  4937,
#  27852,
#  82928,
#  49060,
#  81324,
#  46932,
#  8431,
#  16688,
#  1397,
#  532,
#  604,
#  471,
#  450,
#  -820670,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -839293,
#  0,
#  2747,
#  56911,
#  5522,
#  178473,
#  156953,
#  83090,
#  0,
#  13769,
#  3944,
#  701,
#  735,
#  4326,
#  0,
#  52446,
#  1558,
#  345319,
#  2193,
#  1510,
#  15093,
#  65294,
#  85491,
#  70622,
#  108498,
#  781595,
#  0,
#  214930,
#  34371,
#  1014353,
#  1448991,
#  7077,
#  247079,
#  516157,
#  332280,
#  4448,
#  327180,
#  334977,
#  5638,
#  32642,
#  94628,
#  54000,
#  87590,
#  51126,
#  9375,
#  18002,
#  1504,
#  603,
#  641,
#  484,
#  477,
#  -624354,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3289,
#  59787,
#  5490,
#  186582,
#  156097,
#  91390,
#  0,
#  14762,
#  3991,
#  764,
#  781,
#  4780,
#  0,
#  47931,
#  8595,
#  420795,
#  2380,
#  2006,
#  15759,
#  64404,
#  131179,
#  83502,
#  134725,
#  579516,
#  0,
#  788248,
#  36344,
#  1039951,
#  1474974,
#  7344,
#  253757,
#  541026,
#  355286,
#  4622,
#  281909,
#  401704,
#  7236,
#  31897,
#  95063,
#  54989,
#  90040,
#  53906,
#  9999,
#  20500,
#  1600,
#  616,
#  686,
#  503,
#  559,
#  -328554,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  410767,
#  53974462,
#  1496355,
#  58042995,
#  58724969,
#  0,
#  3525,
#  62164,
#  5839,
#  210599,
#  174996,
#  99856,
#  0,
#  14901,
#  4123,
#  887,
#  1038,
#  4965,
#  0,
#  45737,
#  10332,
#  464926,
#  2429,
#  1988,
#  16207,
#  73642,
#  149675,
#  122012,
#  149703,
#  719810,
#  0,
#  713077,
#  39011,
#  1157100,
#  1567463,
#  9314,
#  261707,
#  559998,
#  405192,
#  16567,
#  308843,
#  440279,
#  6872,
#  31756,
#  99756,
#  67564,
#  92190,
#  57649,
#  14038,
#  21007,
#  1614,
#  625,
#  772,
#  519,
#  517,
#  -400658,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  142620,
#  60337998,
#  1352749,
#  1522,
#  1879,
#  579593,
#  0,
#  4577482,
#  110658,
#  5935,
#  55102,
#  5345,
#  9645,
#  8658,
#  7681477,
#  4689,
#  59788,
#  127491,
#  7318762,
#  798076,
#  11116952,
#  18154,
#  55290,
#  9691,
#  4425,
#  119418,
#  9249464,
#  63384,
#  1632,
#  6217046,
#  7419839,
#  130300,
#  528839,
#  124860,
#  132780,
#  4155,
#  0,
#  859822,
#  0,
#  20087,
#  5172,
#  6581,
#  830,
#  6429,
#  1323216,
#  96464,
#  627243,
#  3158965,
#  855,
#  7259066,
#  7536,
#  472029,
#  1020440,
#  0,
#  11279,
#  3277,
#  47642,
#  1615875,
#  ...]

# %%
size_array = len(city_fund)
for x in range(size_array):
    y = str(abs(city_fund[x]))
    city_fund[x] = int(y[0])

# %%
one = 0
two = 0
three = 0
four = 0
five = 0
six = 0
seven = 0
eight = 0 
nine = 0
zero = 0
for x in range(size_array):
    if city_fund[x] == 1:
        one  +=  1
    elif city_fund[x] == 2:
        two += 1
    elif city_fund[x] == 3:
        three += 1
    elif city_fund[x] == 4:
        four += 1
    elif city_fund[x] == 5:
        five += 1
    elif city_fund[x] == 6:
        six += 1
    elif city_fund[x] == 7:
        seven += 1
    elif city_fund[x] == 8:
        eight += 1
    elif city_fund[x] == 9:
        nine += 1
    elif city_fund[x] == 0:
        zero += 1

# %%
Benford_assortment = [one, two, three, four, five, six, seven, eight, nine]
Numbers = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(Benford_assortment)
print(sum(Benford_assortment))
# Out:
# [304, 146, 152, 203, 147, 117, 93, 78, 69]
# 1309

# %%
pp.bar(Numbers, Benford_assortment , color ='maroon',  
        width = 0.4) 
  
pp.xlabel("#") 
pp.ylabel("times # appeared") 
pp.title("Benford's Law") 
pp.show()

# %%
size_array = len(all_funds)
for x in range(size_array):
    y = str(abs(all_funds[x]))
    all_funds[x] = int(y[0])

# %%
one = 0
two = 0
three = 0
four = 0
five = 0
six = 0
seven = 0
eight = 0 
nine = 0
zero = 0
for x in range(size_array):
    if all_funds[x] == 1:
        one  +=  1
    elif all_funds[x] == 2:
        two += 1
    elif all_funds[x] == 3:
        three += 1
    elif all_funds[x] == 4:
        four += 1
    elif all_funds[x] == 5:
        five += 1
    elif all_funds[x] == 6:
        six += 1
    elif all_funds[x] == 7:
        seven += 1
    elif all_funds[x] == 8:
        eight += 1
    elif all_funds[x] == 9:
        nine += 1
    elif all_funds[x] == 0:
        zero += 1

# %%
Benford_assortment = [one, two, three, four, five, six, seven, eight, nine]
Numbers = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(Benford_assortment)
print(sum(Benford_assortment))
# Out:
# [351, 170, 131, 176, 128, 107, 79, 102, 84]
# 1328

# %%
pp.bar(Numbers, Benford_assortment , color ='maroon',  
        width = 0.4) 
  
pp.xlabel("#") 
pp.ylabel("times # appeared") 
pp.title("Benford's Law") 
pp.show()
